# %% [markdown]
# # CODING TASK #1. IMPORT DATA

# %%
import pandas as pd

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
employee_df.describe()
# Out:
#               Salary  Years with Company
# count      10.000000            10.00000
# mean    22140.013000            10.10000
# std     30613.044026             6.52261
# min      2629.130000             2.00000
# 25%      5906.740000             5.50000
# 50%      9536.010000             9.50000
# 75%     17768.005000            12.75000
# max    100000.000000            23.00000

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **What's the name of the employee who was most loyal to the company?**
# - **How can you filter out this employee features using Pandas? [external research is required]**

# %%
#What's the name of the employee who was most loyal to the company?
most_loyal_employee = employee_df[ employee_df['Years with Company'] == 23]
most_loyal_employee
# Out:
#   First Name Last Name  Salary  Years with Company Postal Code  \
# 4       Kate      Noor  5000.0                  23     K8N 5H6
#
#               Email
# 4  kate@hotmail.com

# %% [markdown]
# # CODING TASK #2. SELECTING COLUMNS FROM A DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Return a column from the DataFrame
# Note that the output will be a Pandas Series (you can automatically tell by the lack of formating)
sample = employee_df['Email']
sample
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Confirm the datatype of sample
type(sample)
# Out:
# pandas.core.series.Series

# %%
# Alternatively, you can use the following syntax to do the same
# Note that this method will not work if there are spaces in the column names
employee_df.Email
# Out:
# 0             bird@gmail.com
# 1         nsmall@hotmail.com
# 2            azikez@gahew.mr
# 3           chanel@gmail.com
# 4           kate@hotmail.com
# 5            samer@gmail.com
# 6    heba.ismail@hotmail.com
# 7        Laila.a@hotmail.com
# 8             daafeja@boh.jm
# 9          guutodi@bigwoc.kw
# Name: Email, dtype: object

# %%
# Since the column name has spaces, this will be the only way that will work!
employee_df['Years with Company']
# Out:
# 0     3
# 1     8
# 2    17
# 3    12
# 4    23
# 5    13
# 6     7
# 7     5
# 8     2
# 9    11
# Name: Years with Company, dtype: int64

# %%
# Let's select multiple columns from the DataFrame
# you need to define a list containing all column names that you would like to select
# Note that since we collected more than one column, the output is a DataFrame (Notice the rich formatting)
sample = employee_df[['First Name', 'Salary']]
sample
# Out:
#   First Name     Salary
# 0       Mike    5000.00
# 1       Noah   10000.00
# 2       Nina    9072.02
# 3    Chanel    11072.02
# 4       Kate    5000.00
# 5      Samer  100000.00
# 6       Heba   50000.00
# 7      Laila   20000.00
# 8     Joseph    2629.13
# 9       Noah    8626.96

# %%
# Note that sample is now a DataFrame and not a Pandas Series (since it has multiple columns)
# You can use type to confirm or you can tell from the rich text formating
type(sample)
# Out:
# pandas.core.series.Series

# %%
# In order to access a given row in the dataframe
employee_df[0:3]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.00                   3     N94 3M0
# 1       Noah      Ryan  10000.00                   8     N8S 14K
# 2       Nina    Keller   9072.02                  17     S1T 4E6
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com
# 2     azikez@gahew.mr

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
# - **Select the following columns from the dataFrame Salary, Years with Company, and Postal Code**

# %%
#My solution 
selected_cols = ['Salary', 'Years with Company', 'Postal Code'] 
sample = employee_df[selected_cols]
sample
# Out:
#       Salary  Years with Company Postal Code
# 0    5000.00                   3     N94 3M0
# 1   10000.00                   8     N8S 14K
# 2    9072.02                  17     S1T 4E6
# 3   11072.02                  12     N7T 3E6
# 4    5000.00                  23     K8N 5H6
# 5  100000.00                  13     J7H 3HY
# 6   50000.00                   7     K8Y 3M8
# 7   20000.00                   5     J8Y 3M0
# 8    2629.13                   2     M6U 5U7
# 9    8626.96                  11     K2D 4M9

# %% [markdown]
# # CODING TASK #3. ADDING/DELETING COLUMNS TO DATAFRAME

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Let's assume that we want to add a new column to the dataframe
employee_df['Age'] = [25, 26, 28, 30, 36, 22, 48, 55, 70, 69]

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email  Age
# 0           bird@gmail.com   25
# 1       nsmall@hotmail.com   26
# 2          azikez@gahew.mr   28
# 3         chanel@gmail.com   30
# 4         kate@hotmail.com   36
# 5          samer@gmail.com   22
# 6  heba.ismail@hotmail.com   48
# 7      Laila.a@hotmail.com   55
# 8           daafeja@boh.jm   70
# 9        guutodi@bigwoc.kw   69

# %%
# You can also insert a new column in a given position 
employee_df.insert(0, column = 'Credit Score', value = [680, 700, 750, 699, 550, 600, 750, 500, 520, 510])

# %%
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           680       Mike       Moe    5000.00                   3
# 1           700       Noah      Ryan   10000.00                   8
# 2           750       Nina    Keller    9072.02                  17
# 3           699    Chanel      Steve   11072.02                  12
# 4           550       Kate      Noor    5000.00                  23
# 5           600      Samer        Mo  100000.00                  13
# 6           750       Heba     Steve   50000.00                   7
# 7           500      Laila       Aly   20000.00                   5
# 8           520     Joseph    Patton    2629.13                   2
# 9           510       Noah     Moran    8626.96                  11
#
#   Postal Code                    Email  Age
# 0     N94 3M0           bird@gmail.com   25
# 1     N8S 14K       nsmall@hotmail.com   26
# 2     S1T 4E6          azikez@gahew.mr   28
# 3     N7T 3E6         chanel@gmail.com   30
# 4     K8N 5H6         kate@hotmail.com   36
# 5     J7H 3HY          samer@gmail.com   22
# 6     K8Y 3M8  heba.ismail@hotmail.com   48
# 7     J8Y 3M0      Laila.a@hotmail.com   55
# 8     M6U 5U7           daafeja@boh.jm   70
# 9     K2D 4M9        guutodi@bigwoc.kw   69

# %%
# Delete a column from a DataFrame
del employee_df['Email']
employee_df
# Out:
#    Credit Score First Name Last Name     Salary  Years with Company  \
# 0           680       Mike       Moe    5000.00                   3
# 1           700       Noah      Ryan   10000.00                   8
# 2           750       Nina    Keller    9072.02                  17
# 3           699    Chanel      Steve   11072.02                  12
# 4           550       Kate      Noor    5000.00                  23
# 5           600      Samer        Mo  100000.00                  13
# 6           750       Heba     Steve   50000.00                   7
# 7           500      Laila       Aly   20000.00                   5
# 8           520     Joseph    Patton    2629.13                   2
# 9           510       Noah     Moran    8626.96                  11
#
#   Postal Code  Age
# 0     N94 3M0   25
# 1     N8S 14K   26
# 2     S1T 4E6   28
# 3     N7T 3E6   30
# 4     K8N 5H6   36
# 5     J7H 3HY   22
# 6     K8Y 3M8   48
# 7     J8Y 3M0   55
# 8     M6U 5U7   70
# 9     K2D 4M9   69

# %%
employee_df.drop(labels = ["Last Name", "Salary"], axis = 1, inplace = True)
employee_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-5297c169bbd6> in <module>
# ----> 1 employee_df.drop(labels = ["Last Name", "Salary"], axis = 1, inplace = True)
#       2 employee_df
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Last Name' 'Salary'] not found in axis"

# %%
# Remove a column from a DataFrame and store it somehwere else using pop
Years_with_company = employee_df.pop("Years with Company")
Years_with_company
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Years with Company'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-a3da0b7731e2> in <module>
#       1 # Remove a column from a DataFrame and store it somehwere else using pop
# ----> 2 Years_with_company = employee_df.pop("Years with Company")
#       3 Years_with_company
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in pop(self, item)
#    5224         3  monkey        NaN
#    5225         """
# -> 5226         return super().pop(item=item)
#    5227
#    5228     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in pop(self, item)
#     868
#     869     def pop(self, item: Hashable) -> Series | Any:
# --> 870         result = self[item]
#     871         del self[item]
#     872
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Years with Company'

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **load the employee_information.csv file and perform the following: (assume any reasonable values)**
#     - **Add a column indicating whether the employee has a mortgage or not**
#     - **Add a column indicating the value of mortage in dollars**

# %%
#My solution
empl_info_df = pd.read_csv('employee_information.csv')
empl_info_df.head()
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.00                   3     N94 3M0
# 1       Noah      Ryan  10000.00                   8     N8S 14K
# 2       Nina    Keller   9072.02                  17     S1T 4E6
# 3    Chanel      Steve  11072.02                  12     N7T 3E6
# 4       Kate      Noor   5000.00                  23     K8N 5H6
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com
# 2     azikez@gahew.mr
# 3    chanel@gmail.com
# 4    kate@hotmail.com

# %%
empl_info_df['Has mortgage']   = ["Yes", "Yes", "No", "Yes", "Yes", "No", "No", "No", "No", "Yes"]
empl_info_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email Has mortgage
# 0           bird@gmail.com          Yes
# 1       nsmall@hotmail.com          Yes
# 2          azikez@gahew.mr           No
# 3         chanel@gmail.com          Yes
# 4         kate@hotmail.com          Yes
# 5          samer@gmail.com           No
# 6  heba.ismail@hotmail.com           No
# 7      Laila.a@hotmail.com           No
# 8           daafeja@boh.jm           No
# 9        guutodi@bigwoc.kw          Yes

# %%
#Add column indicating value of the mortgage
empl_info_df['mortage value($)'] = ["100k", "400k", "", "1M", "150k", "400k", "", "", "", "20M"]
empl_info_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email Has mortgage mortage value($)
# 0           bird@gmail.com          Yes             100k
# 1       nsmall@hotmail.com          Yes             400k
# 2          azikez@gahew.mr           No
# 3         chanel@gmail.com          Yes               1M
# 4         kate@hotmail.com          Yes             150k
# 5          samer@gmail.com           No             400k
# 6  heba.ismail@hotmail.com           No
# 7      Laila.a@hotmail.com           No
# 8           daafeja@boh.jm           No
# 9        guutodi@bigwoc.kw          Yes              20M

# %% [markdown]
# # CODING TASK #4. LABEL-BASED ELEMENTS SELECTION FROM A DATAFRAME ".LOC()"

# %%
# Load the csv file and set the last name as the index
employee_df = pd.read_csv('employee_information.csv', index_col = 'Last Name')
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Moe             Mike    5000.00                   3     N94 3M0
# Ryan            Noah   10000.00                   8     N8S 14K
# Keller          Nina    9072.02                  17     S1T 4E6
# Steve        Chanel    11072.02                  12     N7T 3E6
# Noor            Kate    5000.00                  23     K8N 5H6
# Mo             Samer  100000.00                  13     J7H 3HY
# Steve           Heba   50000.00                   7     K8Y 3M8
# Aly            Laila   20000.00                   5     J8Y 3M0
# Patton        Joseph    2629.13                   2     M6U 5U7
# Moran           Noah    8626.96                  11     K2D 4M9
#
#                              Email
# Last Name
# Moe                 bird@gmail.com
# Ryan            nsmall@hotmail.com
# Keller             azikez@gahew.mr
# Steve             chanel@gmail.com
# Noor              kate@hotmail.com
# Mo                 samer@gmail.com
# Steve      heba.ismail@hotmail.com
# Aly            Laila.a@hotmail.com
# Patton              daafeja@boh.jm
# Moran            guutodi@bigwoc.kw

# %%
# Sort the dataframe in an alphabetical order
employee_df.sort_index(inplace = True)

# %%
employee_df
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
# Moran           Noah    8626.96                  11     K2D 4M9
# Noor            Kate    5000.00                  23     K8N 5H6
# Patton        Joseph    2629.13                   2     M6U 5U7
# Ryan            Noah   10000.00                   8     N8S 14K
# Steve        Chanel    11072.02                  12     N7T 3E6
# Steve           Heba   50000.00                   7     K8Y 3M8
#
#                              Email
# Last Name
# Aly            Laila.a@hotmail.com
# Keller             azikez@gahew.mr
# Mo                 samer@gmail.com
# Moe                 bird@gmail.com
# Moran            guutodi@bigwoc.kw
# Noor              kate@hotmail.com
# Patton              daafeja@boh.jm
# Ryan            nsmall@hotmail.com
# Steve             chanel@gmail.com
# Steve      heba.ismail@hotmail.com

# %%
# loc is used to filter rows and columns
# loc is label-based meaning you need to give a name of the rows (or columns) that you are interested in selecting
# Note that iloc is "integer index-based" meaning you can filter rows/columns by their integer index.
# Note that we obtained a Series because last name "Aly" existed only once in the dataframe

employee_df.loc['Aly']
# Out:
# First Name                          Laila
# Salary                            20000.0
# Years with Company                      5
# Postal Code                       J8Y 3M0
# Email                 Laila.a@hotmail.com
# Name: Aly, dtype: object

# %%
# Note that you can select multiple rows using "colon :"
# Note that this is inclusive! meaning that "Aly" and "Patton" were selected in the output DataFrame
# Headsup: this will be different if we use integer based index such as iloc()

employee_df.loc['Aly':'Patton']
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila   20000.00                   5     J8Y 3M0
# Keller          Nina    9072.02                  17     S1T 4E6
# Mo             Samer  100000.00                  13     J7H 3HY
# Moe             Mike    5000.00                   3     N94 3M0
# Moran           Noah    8626.96                  11     K2D 4M9
# Noor            Kate    5000.00                  23     K8N 5H6
# Patton        Joseph    2629.13                   2     M6U 5U7
#
#                          Email
# Last Name
# Aly        Laila.a@hotmail.com
# Keller         azikez@gahew.mr
# Mo             samer@gmail.com
# Moe             bird@gmail.com
# Moran        guutodi@bigwoc.kw
# Noor          kate@hotmail.com
# Patton          daafeja@boh.jm

# %%
# Select all elements up to and including 'Keller' index
employee_df.loc[:'Keller']
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Aly            Laila  20000.00                   5     J8Y 3M0
# Keller          Nina   9072.02                  17     S1T 4E6
#
#                          Email
# Last Name
# Aly        Laila.a@hotmail.com
# Keller         azikez@gahew.mr

# %%
# if you want to select multiple rows, you can pass them as a list as follows
employee_df.loc[["Keller", "Steve", "Mo"]]
# Out:
#           First Name     Salary  Years with Company Postal Code  \
# Last Name
# Keller          Nina    9072.02                  17     S1T 4E6
# Steve        Chanel    11072.02                  12     N7T 3E6
# Steve           Heba   50000.00                   7     K8Y 3M8
# Mo             Samer  100000.00                  13     J7H 3HY
#
#                              Email
# Last Name
# Keller             azikez@gahew.mr
# Steve             chanel@gmail.com
# Steve      heba.ismail@hotmail.com
# Mo                 samer@gmail.com

# %%
# You can also randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns
employee_df.sample(n = 5, axis = 0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Moran           Noah   8626.96                  11     K2D 4M9
# Aly            Laila  20000.00                   5     J8Y 3M0
# Steve        Chanel   11072.02                  12     N7T 3E6
# Ryan            Noah  10000.00                   8     N8S 14K
# Patton        Joseph   2629.13                   2     M6U 5U7
#
#                          Email
# Last Name
# Moran        guutodi@bigwoc.kw
# Aly        Laila.a@hotmail.com
# Steve         chanel@gmail.com
# Ryan        nsmall@hotmail.com
# Patton          daafeja@boh.jm

# %%
# return a percentage (Ex: 30%) of the rows 
employee_df.sample(frac = 0.3, axis = 0)
# Out:
#           First Name    Salary  Years with Company Postal Code  \
# Last Name
# Patton        Joseph   2629.13                   2     M6U 5U7
# Aly            Laila  20000.00                   5     J8Y 3M0
# Keller          Nina   9072.02                  17     S1T 4E6
#
#                          Email
# Last Name
# Patton          daafeja@boh.jm
# Aly        Laila.a@hotmail.com
# Keller         azikez@gahew.mr

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Load the 'employee_information.csv' data and use the "first name" column as the index**
# - **Randomly select 2 rows from the DataFrame. Rerun the code and ensure that random rows are being selected**

# %%
#My solution
empl_df = pd.read_csv('employee_information.csv', index_col = 'First Name')
empl_df
# Out:
#            Last Name     Salary  Years with Company Postal Code  \
# First Name
# Mike             Moe    5000.00                   3     N94 3M0
# Noah            Ryan   10000.00                   8     N8S 14K
# Nina          Keller    9072.02                  17     S1T 4E6
# Chanel         Steve   11072.02                  12     N7T 3E6
# Kate            Noor    5000.00                  23     K8N 5H6
# Samer             Mo  100000.00                  13     J7H 3HY
# Heba           Steve   50000.00                   7     K8Y 3M8
# Laila            Aly   20000.00                   5     J8Y 3M0
# Joseph        Patton    2629.13                   2     M6U 5U7
# Noah           Moran    8626.96                  11     K2D 4M9
#
#                               Email
# First Name
# Mike                 bird@gmail.com
# Noah             nsmall@hotmail.com
# Nina                azikez@gahew.mr
# Chanel             chanel@gmail.com
# Kate               kate@hotmail.com
# Samer               samer@gmail.com
# Heba        heba.ismail@hotmail.com
# Laila           Laila.a@hotmail.com
# Joseph               daafeja@boh.jm
# Noah              guutodi@bigwoc.kw

# %%
empl_df.sample(n = 2, axis = 0)
# Out:
#            Last Name   Salary  Years with Company Postal Code            Email
# First Name
# Mike             Moe  5000.00                   3     N94 3M0   bird@gmail.com
# Nina          Keller  9072.02                  17     S1T 4E6  azikez@gahew.mr

# %% [markdown]
# # CODING TASK #5. INTEGER INDEX-BASED ELEMENTS SELECTION FROM A DATAFRAME "iLOC()"

# %%
# Load the CSV file with default index
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# You can access rows with their numeric index using iloc
employee_df.iloc[9]
# Out:
# First Name                         Noah
# Last Name                         Moran
# Salary                          8626.96
# Years with Company                   11
# Postal Code                     K2D 4M9
# Email                 guutodi@bigwoc.kw
# Name: 9, dtype: object

# %%
# You can access multiple rows with their numeric index using iloc and colon :
# Note that using iloc is exclusive, meaning that we did not include the last element (quite confusing I know!)
# We went from index = 2 up until and not including index 5 so index 2,3, and 4 are the one selected
employee_df.iloc[2:5]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 2       Nina    Keller   9072.02                  17     S1T 4E6
# 3    Chanel      Steve  11072.02                  12     N7T 3E6
# 4       Kate      Noor   5000.00                  23     K8N 5H6
#
#               Email
# 2   azikez@gahew.mr
# 3  chanel@gmail.com
# 4  kate@hotmail.com

# %%
# all up until and not including index 4
employee_df.iloc[:4]
# Out:
#   First Name Last Name    Salary  Years with Company Postal Code  \
# 0       Mike       Moe   5000.00                   3     N94 3M0
# 1       Noah      Ryan  10000.00                   8     N8S 14K
# 2       Nina    Keller   9072.02                  17     S1T 4E6
# 3    Chanel      Steve  11072.02                  12     N7T 3E6
#
#                 Email
# 0      bird@gmail.com
# 1  nsmall@hotmail.com
# 2     azikez@gahew.mr
# 3    chanel@gmail.com

# %%
# Multiple elements are selected using a list of indexes 
employee_df.iloc[[2, 4, 9]]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 2       Nina    Keller  9072.02                  17     S1T 4E6
# 4       Kate      Noor  5000.00                  23     K8N 5H6
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 2    azikez@gahew.mr
# 4   kate@hotmail.com
# 9  guutodi@bigwoc.kw

# %%
# Slicing a piece of the dataframe by selecting which row and column you would like to select
employee_df.iloc[4, 0:3]
# Out:
# First Name      Kate
# Last Name       Noor
# Salary        5000.0
# Name: 4, dtype: object

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %% [markdown]
# **PRACTICE OPPORTUNITY #5: [OPTIONAL]**
# - **Write a code that selects the last two rows in the DataFrame using two different methods**

# %%
#My Solution
employee_df.iloc[employee_df.shape[0] - 2:]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 8     Joseph    Patton  2629.13                   2     M6U 5U7
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 8     daafeja@boh.jm
# 9  guutodi@bigwoc.kw

# %%
#Another method
employee_df.iloc[8:]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 8     Joseph    Patton  2629.13                   2     M6U 5U7
#
#             Email
# 8  daafeja@boh.jm

# %%
employee_df.iloc[-2:]
# Out:
#   First Name Last Name   Salary  Years with Company Postal Code  \
# 8     Joseph    Patton  2629.13                   2     M6U 5U7
# 9       Noah     Moran  8626.96                  11     K2D 4M9
#
#                Email
# 8     daafeja@boh.jm
# 9  guutodi@bigwoc.kw

# %% [markdown]
# # CODING TASK #6. BROADCASTING OPERATIONS & SETTING NEW DATAFRAME VALUES

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Let's assume that we want to update the salaries of all our employees by $1000
employee_df['Salary'] = employee_df['Salary'] + 1000

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    7000.00                   3     N94 3M0
# 1       Noah      Ryan   12000.00                   8     N8S 14K
# 2       Nina    Keller   11072.02                  17     S1T 4E6
# 3    Chanel      Steve   13072.02                  12     N7T 3E6
# 4       Kate      Noor    7000.00                  23     K8N 5H6
# 5      Samer        Mo  102000.00                  13     J7H 3HY
# 6       Heba     Steve   52000.00                   7     K8Y 3M8
# 7      Laila       Aly   22000.00                   5     J8Y 3M0
# 8     Joseph    Patton    4629.13                   2     M6U 5U7
# 9       Noah     Moran   10626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Alternatively, you can add or subtract as follows
employee_df['Salary'] = employee_df['Salary'].add(1000)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    8000.00                   3     N94 3M0
# 1       Noah      Ryan   13000.00                   8     N8S 14K
# 2       Nina    Keller   12072.02                  17     S1T 4E6
# 3    Chanel      Steve   14072.02                  12     N7T 3E6
# 4       Kate      Noor    8000.00                  23     K8N 5H6
# 5      Samer        Mo  103000.00                  13     J7H 3HY
# 6       Heba     Steve   53000.00                   7     K8Y 3M8
# 7      Laila       Aly   23000.00                   5     J8Y 3M0
# 8     Joseph    Patton    5629.13                   2     M6U 5U7
# 9       Noah     Moran   11626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 
employee_df['Salary (CAD)'] = employee_df['Salary'].mul(1.3)
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    8000.00                   3     N94 3M0
# 1       Noah      Ryan   13000.00                   8     N8S 14K
# 2       Nina    Keller   12072.02                  17     S1T 4E6
# 3    Chanel      Steve   14072.02                  12     N7T 3E6
# 4       Kate      Noor    8000.00                  23     K8N 5H6
# 5      Samer        Mo  103000.00                  13     J7H 3HY
# 6       Heba     Steve   53000.00                   7     K8Y 3M8
# 7      Laila       Aly   23000.00                   5     J8Y 3M0
# 8     Joseph    Patton    5629.13                   2     M6U 5U7
# 9       Noah     Moran   11626.96                  11     K2D 4M9
#
#                      Email  Salary (CAD)
# 0           bird@gmail.com     10400.000
# 1       nsmall@hotmail.com     16900.000
# 2          azikez@gahew.mr     15693.626
# 3         chanel@gmail.com     18293.626
# 4         kate@hotmail.com     10400.000
# 5          samer@gmail.com    133900.000
# 6  heba.ismail@hotmail.com     68900.000
# 7      Laila.a@hotmail.com     29900.000
# 8           daafeja@boh.jm      7317.869
# 9        guutodi@bigwoc.kw     15115.048

# %%
# Decided to update the email address of a given customer
employee_df.iloc[4, 5] = 'kate.noor@gmail.com'

# %%
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    8000.00                   3     N94 3M0
# 1       Noah      Ryan   13000.00                   8     N8S 14K
# 2       Nina    Keller   12072.02                  17     S1T 4E6
# 3    Chanel      Steve   14072.02                  12     N7T 3E6
# 4       Kate      Noor    8000.00                  23     K8N 5H6
# 5      Samer        Mo  103000.00                  13     J7H 3HY
# 6       Heba     Steve   53000.00                   7     K8Y 3M8
# 7      Laila       Aly   23000.00                   5     J8Y 3M0
# 8     Joseph    Patton    5629.13                   2     M6U 5U7
# 9       Noah     Moran   11626.96                  11     K2D 4M9
#
#                      Email  Salary (CAD)
# 0           bird@gmail.com     10400.000
# 1       nsmall@hotmail.com     16900.000
# 2          azikez@gahew.mr     15693.626
# 3         chanel@gmail.com     18293.626
# 4      kate.noor@gmail.com     10400.000
# 5          samer@gmail.com    133900.000
# 6  heba.ismail@hotmail.com     68900.000
# 7      Laila.a@hotmail.com     29900.000
# 8           daafeja@boh.jm      7317.869
# 9        guutodi@bigwoc.kw     15115.048

# %% [markdown]
# **PRACTICE OPPORTUNITY #6 [OPTIONAL]:**
# - **Let's assume that all employees have been performing really well and their salaries have increased by 12% annualy. Calculate the sum of all employees salaries.**

# %%
empl_df = pd.read_csv('employee_information.csv')
empl_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
#Let's increase salary by 12%
empl_df['Salary New']= empl_df['Salary'].mul(1.12)
empl_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email   Salary New
# 0           bird@gmail.com    5600.0000
# 1       nsmall@hotmail.com   11200.0000
# 2          azikez@gahew.mr   10160.6624
# 3         chanel@gmail.com   12400.6624
# 4         kate@hotmail.com    5600.0000
# 5          samer@gmail.com  112000.0000
# 6  heba.ismail@hotmail.com   56000.0000
# 7      Laila.a@hotmail.com   22400.0000
# 8           daafeja@boh.jm    2944.6256
# 9        guutodi@bigwoc.kw    9662.1952

# %%
#Let's sum the entire Salary
total_salary = empl_df['Salary New'].sum()
total_salary
# Out:
# 247968.14560000002

# %% [markdown]
# # CODING TASK #7. PERFORM PANDAS DATAFRAMES SORTING AND ORDERING

# %%
# Let's read a CSV file using Pandas as follows
employee_df = pd.read_csv('employee_information.csv')
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# You can sort the values in the dataframe according to number of years with bank
employee_df.sort_values(by = 'Years with Company')
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
#
#                      Email
# 8           daafeja@boh.jm
# 0           bird@gmail.com
# 7      Laila.a@hotmail.com
# 6  heba.ismail@hotmail.com
# 1       nsmall@hotmail.com
# 9        guutodi@bigwoc.kw
# 3         chanel@gmail.com
# 5          samer@gmail.com
# 2          azikez@gahew.mr
# 4         kate@hotmail.com

# %%
# Note that nothing changed in memory! you have to make sure that inplace is set to True
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
# Set inplace = True to ensure that change has taken place in memory 
employee_df.sort_values(by = 'Years with Company', inplace = True)

# %%
# Note that now the change (ordering) took place 
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
#
#                      Email
# 8           daafeja@boh.jm
# 0           bird@gmail.com
# 7      Laila.a@hotmail.com
# 6  heba.ismail@hotmail.com
# 1       nsmall@hotmail.com
# 9        guutodi@bigwoc.kw
# 3         chanel@gmail.com
# 5          samer@gmail.com
# 2          azikez@gahew.mr
# 4         kate@hotmail.com

# %%
# You can sort the values in a descending order as follows
employee_df.sort_values(by = 'Years with Company', ascending = False, inplace = True) 
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
#
#                      Email
# 4         kate@hotmail.com
# 2          azikez@gahew.mr
# 5          samer@gmail.com
# 3         chanel@gmail.com
# 9        guutodi@bigwoc.kw
# 1       nsmall@hotmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 0           bird@gmail.com
# 8           daafeja@boh.jm

# %%
# You can sort the dataframe with index instead of values as follows
employee_df.sort_index(inplace = True) 
employee_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %% [markdown]
# **PRACTICE OPPORTUNITY #7 [OPTIONAL]:**
# - **Sort employees by salaries instead of years with Company. Make sure to update values in-memory.**

# %%
#My solution
empl_df = pd.read_csv('employee_information.csv')
empl_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 5      Samer        Mo  100000.00                  13     J7H 3HY
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 9       Noah     Moran    8626.96                  11     K2D 4M9
#
#                      Email
# 0           bird@gmail.com
# 1       nsmall@hotmail.com
# 2          azikez@gahew.mr
# 3         chanel@gmail.com
# 4         kate@hotmail.com
# 5          samer@gmail.com
# 6  heba.ismail@hotmail.com
# 7      Laila.a@hotmail.com
# 8           daafeja@boh.jm
# 9        guutodi@bigwoc.kw

# %%
empl_df.sort_values(by = 'Salary', inplace = True)
empl_df
# Out:
#   First Name Last Name     Salary  Years with Company Postal Code  \
# 8     Joseph    Patton    2629.13                   2     M6U 5U7
# 0       Mike       Moe    5000.00                   3     N94 3M0
# 4       Kate      Noor    5000.00                  23     K8N 5H6
# 9       Noah     Moran    8626.96                  11     K2D 4M9
# 2       Nina    Keller    9072.02                  17     S1T 4E6
# 1       Noah      Ryan   10000.00                   8     N8S 14K
# 3    Chanel      Steve   11072.02                  12     N7T 3E6
# 7      Laila       Aly   20000.00                   5     J8Y 3M0
# 6       Heba     Steve   50000.00                   7     K8Y 3M8
# 5      Samer        Mo  100000.00                  13     J7H 3HY
#
#                      Email
# 8           daafeja@boh.jm
# 0           bird@gmail.com
# 4         kate@hotmail.com
# 9        guutodi@bigwoc.kw
# 2          azikez@gahew.mr
# 1       nsmall@hotmail.com
# 3         chanel@gmail.com
# 7      Laila.a@hotmail.com
# 6  heba.ismail@hotmail.com
# 5          samer@gmail.com

# %%
# Get the ten hight Salary
empl_df.iloc[9]['Salary']
# Out:
# 100000.0

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # PRACTICE OPPORTUNITIES SOLUTIONS

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 SOLUTION:**
# - **What's the name of the employee who was most loyal to the company?**
# - **How can you filter out this employee features using Pandas? [external research is required]**

# %%
# Kate Noor has been with the company for 23 years

# %%
employee_df[employee_df['Years with Company']==23]

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Select the following columns from the dataFrame Salary, Years with Company, and Postal Code**

# %%
my_selected_columns = ['Salary', 'Years with Company', 'Postal Code']
sample = employee_df[my_selected_columns]
sample

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 SOLUTION:**
# - **load the employee_information.csv file and perform the following: (assume any reasonable values)**
#     - **Add a column indicating whether the employee has a mortgage or not**
#     - **Add a column indicating the value of mortage in dollars**

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df

# Let's assume that we want to add a new column to the dataframe
employee_df['Has Mortage'] = [1, 1, 0, 0, 0, 0, 1, 0, 0, 0]
employee_df['Mortage Value'] = [200000, 130000, 0, 0, 0, 0, 400000, 0, 0, 0]
employee_df

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 SOLUTION:**
# - **Load the csv data and use the "first name" column as the index**
# - **Randomly select 2 rows from the DataFrame. Rerun the code and ensure that random rows are being selected**

# %%
# Load the csv file and set the last name as the index
employee_df = pd.read_csv('employee_information.csv', index_col = 'First Name')
employee_df

# You can also randomly select a fraction of the DataFrame
# Setting axis = 0 means rows, setting index = 1 means columns
employee_df.sample(n = 2, axis = 0)

# %% [markdown]
# **PRACTICE OPPORTUNITY #5 SOLUTION:**
# - **Write a code that selects the last two rows in the DataFrame using two different methods**

# %%
employee_df.iloc[8:]

# %%
employee_df.iloc[-2:]

# %% [markdown]
# **PRACTICE OPPORTUNITY #6 SOLUTION:**
# - **Let's assume that all employees have been performing really well and their salaries have increased by 12% annualy. Calculate the sum of all employees salaries.**

# %%
# Pandas is used to read a csv file and store data in a DataFrame
employee_df = pd.read_csv('employee_information.csv')
employee_df

# %%
# Let's convert from USD to CAD using the exchange rate 1 USD = 1.3 CAD 
employee_df['Salary New'] = employee_df['Salary'].mul(1.12)
employee_df

# %%
employee_df['Salary New'].sum()

# %%
print("Total networth for all clients = ${}".format( employee_df['Salary New'].sum()))

# %% [markdown]
# **PRACTICE OPPORTUNITY #7 SOLUTION:**
# - **Sort employees by salaries instead of years with Company. Make sure to update values in-memory.**

# %%
# You can sort the values in the dataframe according to number of years with bank
employee_df.sort_values(by = 'Salary', inplace = True) 
employee_df
